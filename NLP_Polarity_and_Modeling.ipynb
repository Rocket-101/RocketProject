# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd# Import Library
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import urllib.request
import datetime
from datetime import datetime
import nltk
from tqdm import tqdm
from nltk import word_tokenize
from nltk.corpus import PlaintextCorpusReader
from pandas_datareader import data as web
import os
import string
import requests
import datetime
import matplotlib.pyplot as plt
import urllib.request
import datetime
from datetime import datetime
import nltk
from tqdm import tqdm
from pandas_datareader import data as web
import os
import string
import requests
import datetime
import nltk
from nltk import word_tokenize
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
import re
import string

# %%
Y = pd.read_csv("LabeledY.csv")
X = pd.read_csv("newscleaned2.csv")

# %%
Y.head()
# Out:
#    Unnamed: 0  Attributes         High          Low         Open        Close  \
# 0           2  2016-09-26  2158.540039  2145.040039  2158.540039  2146.100098
# 1           3  2016-09-27  2161.129883  2141.550049  2146.040039  2159.929932
# 2           4  2016-09-28  2172.399902  2151.790039  2161.850098  2171.370117
# 3           5  2016-09-29  2172.669922  2145.199951  2168.899902  2151.129883
# 4           6  2016-09-30  2175.300049  2156.510010  2156.510010  2168.270020
#
#        Volume    Adj Close  Daily Growth  LabledY
# 0  3216170000  2146.100098     -0.005763       -1
# 1  3437770000  2159.929932      0.006472        1
# 2  3891460000  2171.370117      0.004404        0
# 3  4249220000  2151.129883     -0.008193       -1
# 4  4173340000  2168.270020      0.005453        0

# %%
X.head()
# Out:
#    Unnamed: 0        Date                                         News_title  \
# 0           0  2016-09-26  additional skyhigh peres loss export lineup cr...
# 1           1  2016-09-27  blunt restoration peres loss wealth list fisch...
# 2           2  2016-09-28  better lyft chemical peres loss knew robert li...
# 3           3  2016-09-29  viral peres loss sound list credit pass rip la...
# 4           4  2016-09-30  peres loss reviewing list robert stance charlo...
#
#                                        News_abstract
# 0  bare rescind prevent chemical include accompan...
# 1  version oppose loss export according list food...
# 2  assuming chemical theatre loss export conducte...
# 3  spurring mishandled export according transpare...
# 4  fled version blunt persisted include peres los...

# %% [markdown]
# ### News Data segmentation and Polarity Analysis
