# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import datetime as datetime
import nltk
import seaborn
import csv
from bs4 import BeautifulSoup
from sklearn import datasets, linear_model
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from sklearn.model_selection import train_test_split 
from wordcloud import WordCloud,STOPWORDS
import matplotlib.pyplot as plt
nltk.download('vader_lexicon')
from subprocess import check_output
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.linear_model import LinearRegression
import seaborn as sns
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.sandbox.regression.predstd import wls_prediction_std
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %% [markdown]
# # stock price process

# %% [markdown]
# ### convert string variable into float variable and calculate two new variable

# %%
def my_fun1(a,b):
    return float(a) - float(b) 

def my_fun2(a):
    return float(a)

MarketData = pd.read_csv('LabeledY.csv')
MarketData
MarketData['HighMinusLow'] = MarketData.apply(lambda x: my_fun1(x['High'],x['Low']),axis=1)
MarketData['CloseMinusOpen'] = MarketData.apply(lambda x: my_fun1(x['Adj Close'],x['Open']),axis=1)
MarketData['High'] = MarketData.apply(lambda x: my_fun2(x['High']),axis=1)
MarketData['Low'] = MarketData.apply(lambda x: my_fun2(x['Low']),axis=1)
MarketData['Open'] = MarketData.apply(lambda x: my_fun2(x['Open']),axis=1)
MarketData['Adj Close'] = MarketData.apply(lambda x: my_fun2(x['Adj Close']),axis=1)
MarketData['Daily Growth'] = MarketData.apply(lambda x: my_fun2(x['Daily Growth']),axis=1)
MarketData['LabledY'] = MarketData.apply(lambda x: my_fun2(x['LabledY']),axis=1)
MarketData
#MarketData.plot()
# Out:
#      Unnamed: 0  Attributes         High          Low         Open  \
# 0             2  2016-09-26  2158.540039  2145.040039  2158.540039
# 1             3  2016-09-27  2161.129883  2141.550049  2146.040039
# 2             4  2016-09-28  2172.399902  2151.790039  2161.850098
# 3             5  2016-09-29  2172.669922  2145.199951  2168.899902
# 4             6  2016-09-30  2175.300049  2156.510010  2156.510010
# 5             7  2016-10-03  2164.409912  2154.770020  2164.330078
# 6             8  2016-10-04  2165.459961  2144.010010  2163.370117
# 7             9  2016-10-05  2163.949951  2155.149902  2155.149902
# 8            10  2016-10-06  2162.929932  2150.280029  2158.219971
# 9            11  2016-10-07  2165.860107  2144.850098  2164.189941
# 10           12  2016-10-10  2169.600098  2160.389893  2160.389893
# 11           13  2016-10-11  2161.560059  2128.840088  2161.350098
# 12           14  2016-10-12  2145.360107  2132.770020  2137.669922
# 13           15  2016-10-13  2138.189941  2114.719971  2130.260010
# 14           16  2016-10-14  2149.189941  2132.979980  2139.679932
# 15           17  2016-10-17  2135.610107  2124.429932  2132.949951
# 16           18  2016-10-18  2144.379883  2135.489990  2138.310059
# 17           19  2016-10-19  2148.439941  2138.149902  2140.810059
# 18           20  2016-10-20  2147.179932  2133.439941  2142.510010
# 19           21  2016-10-21  2142.629883  2130.090088  2139.429932
# 20           22  2016-10-24  2154.790039  2146.909912  2148.500000
# 21           23  2016-10-25  2151.439941  2141.929932  2149.719971
# 22           24  2016-10-26  2145.729980  2131.590088  2136.969971
# 23           25  2016-10-27  2147.129883  2132.520020  2144.060059
# 8       12.649902        2.550049
# 9       21.010010      -10.449951
# 10       9.210205        3.270020
# 11      32.719971      -24.620117
# 12      12.590088        1.510010
# 13      23.469971        2.290039
# 14      16.209961       -6.699951
# 15      11.180176       -6.449951
# 16       8.889893        1.290039
# 17      10.290039        3.479980
# 18      13.739990       -1.169922
# 19      12.539795        1.729980
# 20       7.880127        2.830078
# 21       9.510010       -6.560059
# 22      14.139893        2.459961
# 23      14.609863      -11.020020
# 24      21.359863       -5.820068
# 25       7.719971       -3.630127
# 26      33.599854      -16.959961
# 27      17.760010      -11.489990
# 28      17.330078      -10.140137
# 29      15.280029        1.389893
# ..            ...             ...
# 478      9.139893        3.120117
# 479     11.909912        1.449951
# 480     11.489990        0.830078
# 481     14.750000       -3.310059
# 482     13.809814       12.339844
# 483     13.560059       12.050049
# 484     10.270020       -3.929932
# 485     18.100098       13.419922
# 486     17.239990       -7.810059
# 487     14.590088        3.149902
# 488     15.050049       -0.239990
# 489     17.290039       -2.989990
# 490     24.760010      -10.589844
# 491     19.689941        3.419922
# 492     10.989990       -4.260010
# 493     25.739990       16.319824
# 494     15.449951        0.629883
# 495     10.370117        7.329834
# 496     12.530029       -1.399902
# 497     18.489990      -15.030029
# 498     20.739990       13.570068
# 499      8.540039        1.349854
# 500     15.070068       11.020020
# 501     13.799805       -7.090088
# 502     11.160156       -2.459961
# 503     10.250000       -6.189941
# 504     27.869873      -11.010010
# 505     17.949951        2.350098
# 506     13.030029        3.949951
# 507     19.150146       -1.699951
#
# [508 rows x 12 columns]

# %% [markdown]
# ### mean of stock data

# %%
Market_Mean = MarketData.mean(axis=0)
Market_Mean_1 = Market_Mean[1:5]
ax = Market_Mean_1.plot(title='price mean', kind='bar')
ax.set_xlabel("Price Type",fontsize=12)
ax.set_ylabel("Price",fontsize=12)
plt.ylim(2515, 2545)
plt.show()

# %% [markdown]
# ### News sentiment analysis

# %%
# extract News_title and News_abstract 
news = pd.read_csv('WSJ_news.csv')
#news = pd.read_csv('WSJ_news.csv')
news_title = news['News_title']
news_abs = news['News_abstract']
sid = SentimentIntensityAnalyzer()

# %%
#calculate sentiment score of News_title
date = news['Date']
news_scores_title = []
n = 508
for i in range(n):
    message_text = news_title[i]
    scores = sid.polarity_scores(message_text)
    a = [[date[i],scores['compound']]]
    news_scores_title.extend(a)

title_score1 = pd.DataFrame(news_scores_title,columns = ['Attributes','title_score1'])
title_score1
# Out:
#      Attributes  title_score1
# 0    2016-09-26        0.9508
# 1    2016-09-27        0.9881
# 2    2016-09-28       -0.9888
# 3    2016-09-29        0.9911
# 4    2016-09-30       -0.8984
# 5    2016-10-03       -0.9835
# 6    2016-10-04        0.9782
# 7    2016-10-05       -0.7556
# 8    2016-10-06       -0.9891
# 9    2016-10-07        0.8677
# 10   2016-10-10       -0.9567
# 11   2016-10-11       -0.8435
# 12   2016-10-12       -0.9323
# 13   2016-10-13       -0.9896
# 14   2016-10-14        0.9488
# 15   2016-10-17       -0.9461
# 16   2016-10-18       -0.6646
# 17   2016-10-19        0.9593
# 18   2016-10-20       -0.5286
# 19   2016-10-21        0.9911
# 20   2016-10-24       -0.7673
# 21   2016-10-25        0.8152
# 22   2016-10-26        0.9949
# 23   2016-10-27        0.9978
# 24   2016-10-28       -0.8836
# 25   2016-10-31       -0.6940
# 26   2016-11-01       -0.9830
# 27   2016-11-02       -0.7175
# 28   2016-11-03        0.9913
# 29   2016-11-04       -0.9865
# ..          ...           ...
# 478  2018-08-20       -0.9904
# 479  2018-08-21        0.8106
# 480  2018-08-22        0.8979
# 481  2018-08-23       -0.9941
# 482  2018-08-24        0.9827
# 483  2018-08-27       -0.9384
# 484  2018-08-28       -0.7383
# 485  2018-08-29       -0.9865
# 486  2018-08-30       -0.9751
# 487  2018-08-31       -0.9849
# 488  2018-09-04       -0.9820
# 489  2018-09-05       -0.9738
# 490  2018-09-06        0.9815
# 491  2018-09-07       -0.9957
# 492  2018-09-10       -0.9717
# 493  2018-09-11       -0.9122
# 494  2018-09-12       -0.9650
# 495  2018-09-13       -0.9939
# 496  2018-09-14        0.8172
# 497  2018-09-17        0.1571
# 498  2018-09-18        0.9922
# 499  2018-09-19       -0.9819
# 500  2018-09-20       -0.9925
# 501  2018-09-21       -0.8723
# 502  2018-09-24       -0.5980
# 503  2018-09-25       -0.9433
# 504  2018-09-26        0.9804
# 505  2018-09-27        0.9930
# 506  2018-09-28        0.8230
# 507  2018-10-01        0.9926
#
# [508 rows x 2 columns]

# %%
#calculate sentiment score of News_abstract
news_scores_abs = []
n = 508
for i in range(n):
    message_text = news_abs[i]
    scores = sid.polarity_scores(message_text)
    a = [[date[i],scores['compound']]]
    news_scores_abs.extend(a)

abs_score1 = pd.DataFrame(news_scores_abs,columns = ['Attributes','abs_score1'])
abs_score1
# Out:
#      Attributes  abs_score1
# 0    2016-09-26      0.9990
# 1    2016-09-27      0.9976
# 2    2016-09-28      0.9942
# 3    2016-09-29      0.9987
# 4    2016-09-30      0.9958
# 5    2016-10-03      0.9949
# 6    2016-10-04     -0.6473
# 7    2016-10-05      0.9986
# 8    2016-10-06      0.9768
# 9    2016-10-07      0.9935
# 10   2016-10-10      0.9832
# 11   2016-10-11      0.9991
# 12   2016-10-12     -0.9986
# 13   2016-10-13     -0.9832
# 14   2016-10-14      0.9366
# 15   2016-10-17      0.9984
# 16   2016-10-18      0.9996
# 17   2016-10-19      0.9993
# 18   2016-10-20      0.7945
# 19   2016-10-21      0.9994
# 20   2016-10-24      0.9978
# 21   2016-10-25      0.9993
# 22   2016-10-26      0.9991
# 23   2016-10-27      0.9998
# 24   2016-10-28      0.9989
# 25   2016-10-31      0.9946
# 26   2016-11-01      0.9991
# 27   2016-11-02      0.9975
# 28   2016-11-03      0.9973
# 29   2016-11-04     -0.9938
# ..          ...         ...
# 478  2018-08-20      0.9986
# 479  2018-08-21      0.9977
# 480  2018-08-22      0.9959
# 481  2018-08-23      0.9991
# 482  2018-08-24      0.9956
# 483  2018-08-27      0.9352
# 484  2018-08-28      0.9984
# 485  2018-08-29      0.9989
# 486  2018-08-30      0.9992
# 487  2018-08-31     -0.7417
# 488  2018-09-04      0.9857
# 489  2018-09-05     -0.9652
# 490  2018-09-06      0.9974
# 21       9.510010       -6.560059        0.8152      0.9993
# 22      14.139893        2.459961        0.9949      0.9991
# 23      14.609863      -11.020020        0.9978      0.9998
# 24      21.359863       -5.820068       -0.8836      0.9989
# 25       7.719971       -3.630127       -0.6940      0.9946
# 26      33.599854      -16.959961       -0.9830      0.9991
# 27      17.760010      -11.489990       -0.7175      0.9975
# 28      17.330078      -10.140137        0.9913      0.9973
# 29      15.280029        1.389893       -0.9865     -0.9938
# ..            ...             ...           ...         ...
# 478      9.139893        3.120117       -0.9904      0.9986
# 479     11.909912        1.449951        0.8106      0.9977
# 480     11.489990        0.830078        0.8979      0.9959
# 481     14.750000       -3.310059       -0.9941      0.9991
# 482     13.809814       12.339844        0.9827      0.9956
# 483     13.560059       12.050049       -0.9384      0.9352
# 484     10.270020       -3.929932       -0.7383      0.9984
# 485     18.100098       13.419922       -0.9865      0.9989
# 486     17.239990       -7.810059       -0.9751      0.9992
# 487     14.590088        3.149902       -0.9849     -0.7417
# 488     15.050049       -0.239990       -0.9820      0.9857
# 489     17.290039       -2.989990       -0.9738     -0.9652
# 490     24.760010      -10.589844        0.9815      0.9974
# 491     19.689941        3.419922       -0.9957      0.9940
# 492     10.989990       -4.260010       -0.9717     -0.8739
# 493     25.739990       16.319824       -0.9122     -0.9945
# 494     15.449951        0.629883       -0.9650      0.9993
# 495     10.370117        7.329834       -0.9939     -0.9985
# 496     12.530029       -1.399902        0.8172      0.9991
# 497     18.489990      -15.030029        0.1571      0.9976
# 498     20.739990       13.570068        0.9922      0.9974
# 499      8.540039        1.349854       -0.9819      0.9747
# 500     15.070068       11.020020       -0.9925     -0.9969
# 501     13.799805       -7.090088       -0.8723      0.9971
# 502     11.160156       -2.459961       -0.5980      0.9983
# 503     10.250000       -6.189941       -0.9433      0.9946
# 504     27.869873      -11.010010        0.9804      0.9972
# 505     17.949951        2.350098        0.9930      0.9992
# 506     13.030029        3.949951        0.8230      0.9965
# 507     19.150146       -1.699951        0.9926      0.9986
#
# [508 rows x 14 columns]

# %%
df_combine.to_csv('df_combine.csv')

# %% [markdown]
# ### descrption statistics of sentiment indicator

# %%
df_combine['title_score1'].describe()
# Out:
# count    508.000000
# mean      -0.037688
# std        0.897794
# min       -0.998000
# 25%       -0.966050
# 50%       -0.442700
# 75%        0.965775
# max        0.999500
# Name: title_score1, dtype: float64

# %%
df_combine['abs_score1'].describe()
# Out:
# count    508.000000
# mean       0.675960
# std        0.691189
# min       -0.998600
# 25%        0.959975
# 50%        0.996500
# 75%        0.998900
# max        0.999900
# Name: abs_score1, dtype: float64

# %%
plt.scatter(df_combine['Attributes'],df_combine['title_score1'],edgecolors='none')
plt.show()

# %%
plt.scatter(df_combine['Attributes'],df_combine['abs_score1'],edgecolors='none')
plt.show()

# %%
df_combine['title_score1'].hist()

# %%
df_combine['abs_score1'].hist()

# %% [markdown]
# ### Simple liner regression based on Daily Growth and title_score1 abs_score1

# %%
X1 = df_combine[['title_score1']]
X1_train = X[0:356]
X1_test = X[357:]
X2 = df_combine[['abs_score1']]
X2_train = X[0:356]
X2_test = X[357:]
Y = df_combine[['Daily Growth']]
Y_train = Y[0:356]
Y_test = Y[357:]
Z = df_combine[['Adj Close']]
Z_train = Z[0:356]
Z_test = Z[357:]
T = df_combine[['Attributes']]
T_train = T[0:356]
T_test = T[357:]

# %%
# Use title_score1 and Daily Growth to make simple linear regression
#We should look at Adj. R-squared to judge accuracy of the mode. Here, since Adj. R-squared is so small, the model is not fitted to the dataset.
model = sm.OLS(Y_train, X1_train)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Daily Growth   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7947
# Date:                Sun, 02 Dec 2018   Prob (F-statistic):              0.373
# Time:                        19:01:06   Log-Likelihood:                 1371.5
# No. Observations:                 356   AIC:                            -2741.
# Df Residuals:                     355   BIC:                            -2737.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# title_score1     0.0003      0.000      0.891      0.373      -0.000       0.001
# ==============================================================================
# Omnibus:                      180.490   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4885.956
# Skew:                          -1.529   Prob(JB):                         0.00
# Kurtosis:                      20.890   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Function to show the resutls of linear fit model
def show_linear_line(X_parameters,Y_parameters):
# Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(X_parameters, Y_parameters)
    plt.scatter(X_parameters,Y_parameters,color='blue')
    plt.plot(X_parameters,regr.predict(X_parameters),color='red',linewidth=4)
    plt.xticks(())
    plt.yticks(())
    plt.show()

show_linear_line(X1_train,Y_train)

# %%
# Use abs_score1 and Daily Growth to make simple linear regression
#We should look at Adj. R-squared to judge accuracy of the mode. Here, since Adj. R-squared is so small, the model is not fitted to the dataset.
model = sm.OLS(Y_train, X2_train)
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Daily Growth   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.7947
# Date:                Sun, 02 Dec 2018   Prob (F-statistic):              0.373
# Time:                        19:01:38   Log-Likelihood:                 1371.5
# No. Observations:                 356   AIC:                            -2741.
# Df Residuals:                     355   BIC:                            -2737.
# Df Model:                           1
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# title_score1     0.0003      0.000      0.891      0.373      -0.000       0.001
# ==============================================================================
# Omnibus:                      180.490   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             4885.956
# Skew:                          -1.529   Prob(JB):                         0.00
# Kurtosis:                      20.890   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Function to show the resutls of linear fit model
def show_linear_line(X_parameters,Y_parameters):
# Create linear regression object
    regr = linear_model.LinearRegression()
    regr.fit(X_parameters, Y_parameters)
    plt.scatter(X_parameters,Y_parameters,color='blue')
    plt.plot(X_parameters,regr.predict(X_parameters),color='red',linewidth=4)
    plt.xticks(())
    plt.yticks(())
    plt.show()

show_linear_line(X2_train,Y_train)

# %%
#here, we can conclude that linear regression model does not fit our dataset.

# %% [markdown]
# ### Decision tree model based on Daily Growth and  title_score1 abs_score1

# %%
SPX = df_combine[['Attributes','Adj Close']]
tree = DecisionTreeRegressor().fit(X1_train, Y_train)
score = tree.score(X1_test, Y_test)
score
# Returns the coefficient of determination R^2 of the prediction. ... 
#The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
#Here, we get score -1.49, which is negative, and it indicates that the model is not good.
# Out:
# -0.4486435491780256

# %%
SPX = df_combine[['Attributes','Adj Close']]
tree = DecisionTreeRegressor().fit(X2_train, Y_train)
score = tree.score(X2_test, Y_test)
score
# Returns the coefficient of determination R^2 of the prediction. ... 
#The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
#Here, we get score -1.49, which is negative, and it indicates that the model is not good.
# 24             0.382387      0.039436          0.450671
# 25             0.401736      0.046898          0.425312
# 26             0.389897      0.025765          0.445925
# 27             0.455866      0.010887          0.454362
# 28             0.345998      0.034734          0.423918
# 29             0.420849      0.046110          0.442571
# ..                  ...           ...               ...
# 478            0.383183      0.029879          0.402881
# 479            0.491941      0.066426          0.435689
# 480            0.339376      0.081647          0.407686
# 481            0.392799      0.074250          0.437124
# 482            0.429797      0.059087          0.450512
# 483            0.343677      0.025213          0.422333
# 484            0.418443      0.063504          0.408473
# 485            0.335772      0.053228          0.380037
# 486            0.377848      0.073097          0.415157
# 487            0.523740      0.024069          0.422124
# 488            0.403543      0.112616          0.446079
# 489            0.388628      0.055826          0.446574
# 490            0.439906      0.090996          0.450592
# 491            0.372867      0.035881          0.444529
# 492            0.375352      0.058114          0.389805
# 493            0.317068      0.025281          0.437008
# 494            0.384840      0.075801          0.457047
# 495            0.409931      0.019649          0.445861
# 496            0.377823      0.084282          0.454824
# 497            0.318719      0.018920          0.435233
# 498            0.407630      0.040233          0.442225
# 499            0.397190      0.026401          0.465851
# 500            0.415562      0.049422          0.429072
# 501            0.435000      0.062325          0.445661
# 502            0.363158      0.037779          0.402113
# 503            0.449089      0.061971          0.463318
# 504            0.342282      0.046624          0.445808
# 505            0.462444      0.055710          0.439409
# 506            0.447525      0.067911          0.435112
# 507            0.414284      0.060404          0.489558
#
# [508 rows x 18 columns]

# %%
# Use News_score1 and LabeledY to build decision tree model
X_1 = news_scores[['News_score1']]
X_train_1 = X_1[0:356]
X_test_1 = X_1[357:]
Y_1 = news_scores[['LabeledY']]
Y_train_1 = Y_1[0:356]
Y_test_1 = Y_1[357:]

tree_1 = DecisionTreeRegressor().fit(X_train_1, Y_train_1)
score_1 = tree_1.score(X_test_1, Y_test_1)
score_1
#Returns the coefficient of determination R^2 of the prediction. ... 
#The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
# Out:
# -0.35982578511314145

# %%
# Use News_score2 and LabeledY to build decision tree model
X_2 = news_scores[['News_score2']]
X_train_2 = X_2[0:356]
X_test_2 = X_2[357:]
Y_2 = news_scores[['LabeledY']]
Y_train_2 = Y_2[0:356]
Y_test_2 = Y_2[357:]

tree_2 = DecisionTreeRegressor().fit(X_train_2, Y_train_2)
score_2 = tree_2.score(X_test_2, Y_test_2)
score_2
#Returns the coefficient of determination R^2 of the prediction. ... 
#The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
# Out:
# -0.46304892425582067

# %%
# Use title_polarity, title_subjectivity, abs_polarity, abs_subjectivity and LabeledY to build decision tree model
X_3 = news_scores[['title_polarity','title_subjectivity','abs_polarity','abs_subjectivity']]
X_train_3 = X_3[0:356]
X_test_3 = X_3[357:]
Y_3 = news_scores[['LabeledY']]
Y_train_3 = Y_3[0:356]
Y_test_3 = Y_3[357:]

tree_3 = DecisionTreeRegressor().fit(X_train_3, Y_train_3)
score_3 = tree_3.score(X_test_3, Y_test_3)
score_3
#Returns the coefficient of determination R^2 of the prediction. ... 
#The best possible score is 1.0 and it can be negative (because the model can be arbitrarily worse).
# Out:
# -0.6243737105806071
