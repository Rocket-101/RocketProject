# %%
from IPython import display
import math
from pprint import pprint
import  pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='darkgrid', context='talk', palette='Dark2')

# %%
news_df = pd.read_csv("newscleaned2.csv")
news_df.head()
# Out:
#    Unnamed: 0        Date                                         News_title  \
# 0           0  2016-09-26  additional skyhigh peres loss export lineup cr...
# 1           1  2016-09-27  blunt restoration peres loss wealth list fisch...
# 2           2  2016-09-28  better lyft chemical peres loss knew robert li...
# 3           3  2016-09-29  viral peres loss sound list credit pass rip la...
# 4           4  2016-09-30  peres loss reviewing list robert stance charlo...
#
#                                        News_abstract
# 0  bare rescind prevent chemical include accompan...
# 1  version oppose loss export according list food...
# 2  assuming chemical theatre loss export conducte...
# 3  spurring mishandled export according transpare...
# 4  fled version blunt persisted include peres los...

# %%
#get sentiment score of daily news
import nltk


from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA

sia = SIA()
results = []

for line in news_df['News_title']:
    pol_score = sia.polarity_scores(line)
    pol_score['headline'] = line
    results.append(pol_score)

sent2 = [item['compound'] for item in results]

# %%
senti_df = pd.read_csv('df_combine.csv')

# %%
senti_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Attributes         High          Low  \
# 0           0             2  2016-09-26  2158.540039  2145.040039
# 1           1             3  2016-09-27  2161.129883  2141.550049
# 2           2             4  2016-09-28  2172.399902  2151.790039
# 3           3             5  2016-09-29  2172.669922  2145.199951
# 4           4             6  2016-09-30  2175.300049  2156.510010
#
#           Open        Close      Volume    Adj Close  Daily Growth  LabledY  \
# 0  2158.540039  2146.100098  3216170000  2146.100098     -0.005763     -1.0
# 1  2146.040039  2159.929932  3437770000  2159.929932      0.006472      1.0
# 2  2161.850098  2171.370117  3891460000  2171.370117      0.004404      0.0
# 3  2168.899902  2151.129883  4249220000  2151.129883     -0.008193     -1.0
# 4  2156.510010  2168.270020  4173340000  2168.270020      0.005453      0.0
#
#    HighMinusLow  CloseMinusOpen  sentiment  score2  news_score1
# ...

# %%
senti_df['news_score1'] = senti_df['sentiment']

# %%
senti_df
# Out:
#      Unnamed: 0  Unnamed: 0.1  Attributes         High          Low  \
# 0             0             2  2016-09-26  2158.540039  2145.040039
# 1             1             3  2016-09-27  2161.129883  2141.550049
# 2             2             4  2016-09-28  2172.399902  2151.790039
# 3             3             5  2016-09-29  2172.669922  2145.199951
# 4             4             6  2016-09-30  2175.300049  2156.510010
# 5             5             7  2016-10-03  2164.409912  2154.770020
# 6             6             8  2016-10-04  2165.459961  2144.010010
# 7             7             9  2016-10-05  2163.949951  2155.149902
# 8             8            10  2016-10-06  2162.929932  2150.280029
# 9             9            11  2016-10-07  2165.860107  2144.850098
# 10           10            12  2016-10-10  2169.600098  2160.389893
# 11           11            13  2016-10-11  2161.560059  2128.840088
# 12           12            14  2016-10-12  2145.360107  2132.770020
# ...

# %%
senti_df['news_score2'] = senti_df['score2']

# %%
senti_df=senti_df[['Attributes', 'High','Low','Open','Close','Volume','Adj Close','Daily Growth','LabledY','news_score1','news_score2']]

# %%
senti_df.head()
# Out:
#    Attributes         High          Low         Open        Close      Volume  \
# 0  2016-09-26  2158.540039  2145.040039  2158.540039  2146.100098  3216170000
# 1  2016-09-27  2161.129883  2141.550049  2146.040039  2159.929932  3437770000
# 2  2016-09-28  2172.399902  2151.790039  2161.850098  2171.370117  3891460000
# 3  2016-09-29  2172.669922  2145.199951  2168.899902  2151.129883  4249220000
# 4  2016-09-30  2175.300049  2156.510010  2156.510010  2168.270020  4173340000
#
#      Adj Close  Daily Growth  LabledY  news_score1  news_score2
# 0  2146.100098     -0.005763     -1.0       0.9508       0.3612
# 1  2159.929932      0.006472      1.0       0.9881      -0.9761
# 2  2171.370117      0.004404      0.0      -0.9888      -0.9806
# 3  2151.129883     -0.008193     -1.0       0.9911       0.6249
# 4  2168.270020      0.005453      0.0      -0.8984      -0.9623

# %%
senti_df.to_csv('news_score.csv')
